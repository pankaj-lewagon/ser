# %%
import numpy as np
import pandas as pd
#from ser import extract_feature
import IPython.display as ipd
import librosa 
import librosa.display
import matplotlib as plt
import h5py
import librosabrosa
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/rk/bq7jzz8n0lvc9w7z1d5b87q40000gn/T/ipykernel_48496/1653717046.py in <module>
#       7 import matplotlib as plt
#       8 import h5py
# ----> 9 import librosabrosa
#
# ModuleNotFoundError: No module named 'librosabrosa'

# %%
# IMPORT NECESSARY LIBRARIES
import librosa
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
from IPython.display import Audio
import numpy as np
import tensorflow as tf
from matplotlib.pyplot import specgram
import pandas as pd
from sklearn.metrics import confusion_matrix
import IPython.display as ipd  # To play sound in the notebook
import os # interface with underlying OS that python is running on
import sys
import warnings
# ignore warnings 
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from tensorflow.keras.layers import Input, Flatten, Dropout, Activation, BatchNormalization, Dense
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.regularizers import l2
import seaborn as sns
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report
import soundfile as sf

# %%
# !pwd
# !ls '../raw_data/ravdess-data/Actor_02/03-01-05-01-01-01-02.wav'
# Out:
# /Users/pankajpatel/code/pankaj-lewagon/ser/notebooks
# ../raw_data/ravdess-data/Actor_02/03-01-05-01-01-01-02.wav

# %%
file_name = '../raw_data/ravdess-data/Actor_01/03-01-01-01-01-01-01.wav'
x, sr = librosa.load(file_name)

# %%
x.shape
# Out:
# (72839,)

# %%
# DISPLAY WAVEPLOT
plt.figure(figsize=(8, 4))
librosa.display.waveplot(x, sr=sr)
plt.title('Waveplot - Male Actor Anger')
# Out:
# Text(0.5, 1.0, 'Waveplot - Male Actor Anger')

# %%
ipd.Audio(file_name)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# CREATE LOG MEL SPECTROGRAM
spectrogram = librosa.feature.melspectrogram(y=x, sr=sr, n_mels=128,fmax=8000) 
spectrogram = librosa.power_to_db(spectrogram)

librosa.display.specshow(spectrogram, y_axis='mel', fmax=8000, x_axis='time');
plt.title('Mel Spectrogram - Male Actor Anger')
plt.colorbar(format='%+2.0f dB');

# %%
file_name.split("-")[2]
# Out:
# '01'
